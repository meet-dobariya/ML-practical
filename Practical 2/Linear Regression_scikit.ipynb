# %% [markdown]
# ## Practical 2 : Multiple Linear Regression

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Data Visualization

# %%
sns.jointplot(x=df['age'], y=df['charges'], data=df, kind='reg')

# %%
sns.jointplot(x=df['bmi'], y=df['charges'], data=df, kind='reg')

# %%
X= df[['age']]

Y=df[['charges']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
x_train=x_train['age'].to_numpy()
x_test=x_test['age'].to_numpy()
y_train=y_train['charges'].to_numpy()
y_test=y_test['charges'].to_numpy()


print('Train - Predictors shape', x_train.shape)
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))

#
print('Train - Predictors shape', x_train.shape)
print('Test - Predictors shape', x_test.shape)
print('Train - Target shape', y_train.shape)
print('Test - Target shape', y_test.shape)
# Out:
# Train - Predictors shape (1070,)
# Train - Predictors shape (1070, 1)
# Test - Predictors shape (268, 1)
# Train - Target shape (1070, 1)
# Test - Target shape (268, 1)

# %%
cls = linear_model.LinearRegression()
#Fit method is used for fitting your training data into the model
cls.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = cls.predict(x_test)

# %% [markdown]
# ## Fitting Linear Regression

# %%
cls.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
print('Co-efficient of linear regression',cls.coef_)
# Out:
# Co-efficient of linear regression [[240.59655979]]

# %%
print('Intercept of linear regression model',cls.intercept_)
# Out:
# Intercept of linear regression model [3876.92868419]

# %%
print('Mean Square Error', metrics.mean_squared_error(y_test, prediction))
# Out:
# Mean Square Error 135983957.48054686

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, prediction))
# Out:
# Model R^2 Square value 0.12408973539501966

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, prediction, color='red', linewidth=3)
plt.xlabel('age')
plt.ylabel('charges')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
X= df[['bmi']]

Y=df[['charges']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
x_train=x_train['bmi'].to_numpy()
x_test=x_test['bmi'].to_numpy()
y_train=y_train['charges'].to_numpy()
y_test=y_test['charges'].to_numpy()


print('Train - Predictors shape', x_train.shape)
x_train = np.reshape(x_train, (-1,1))
x_test = np.reshape(x_test, (-1,1))
y_train = np.reshape(y_train, (-1,1))
y_test = np.reshape(y_test, (-1,1))

#
print('Train - Predictors shape', x_train.shape)
print('Test - Predictors shape', x_test.shape)
print('Train - Target shape', y_train.shape)
print('Test - Target shape', y_test.shape)
# Out:
# Train - Predictors shape (1070,)
# Train - Predictors shape (1070, 1)
# Test - Predictors shape (268, 1)
# Train - Target shape (1070, 1)
# Test - Target shape (268, 1)

# %%
cls = linear_model.LinearRegression()
#Fit method is used for fitting your training data into the model
cls.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = cls.predict(x_test)

# %%
print('Co-efficient of linear regression',cls.coef_)
# Out:
# Co-efficient of linear regression [[392.43654417]]

# %%
print('Intercept of linear regression model',cls.intercept_)
# Out:
# Intercept of linear regression model [1353.0730722]

# %%
print('Mean Square Error', metrics.mean_squared_error(y_test, prediction))
# Out:
# Mean Square Error 149085057.03839505

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, prediction))
# Out:
# Model R^2 Square value 0.03970193117941878

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, prediction, color='red', linewidth=3)
plt.xlabel('bmi')
plt.ylabel('charges')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
plt.scatter(cls.predict(x_test), cls.predict(x_test) - y_test, c='g', s = 40)
plt.hlines(y=0, xmin=0, xmax=100)
plt.title('Residual plot')
plt.ylabel('Residual')
# Out:
# Text(0, 0.5, 'Residual')
